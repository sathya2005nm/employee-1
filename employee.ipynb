# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# %%
df=pd.read_csv("employee_survey_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   EnvironmentSatisfaction  4385 non-null   float64
#  2   JobSatisfaction          4390 non-null   float64
#  3   WorkLifeBalance          4372 non-null   float64
# dtypes: float64(3), int64(1)
# memory usage: 137.9 KB

# %%
df
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0              1                      3.0              4.0              2.0
# 1              2                      3.0              2.0              4.0
# 2              3                      2.0              2.0              1.0
# 3              4                      4.0              4.0              3.0
# 4              5                      4.0              1.0              3.0
# ...          ...                      ...              ...              ...
# 4405        4406                      4.0              1.0              3.0
# 4406        4407                      4.0              4.0              3.0
# 4407        4408                      1.0              3.0              3.0
# 4408        4409                      4.0              1.0              3.0
# 4409        4410                      1.0              3.0              NaN
#
# [4410 rows x 4 columns]

# %%
df.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0

# %%
df.tail()
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 4405        4406                      4.0              1.0              3.0
# 4406        4407                      4.0              4.0              3.0
# 4407        4408                      1.0              3.0              3.0
# 4408        4409                      4.0              1.0              3.0
# 4409        4410                      1.0              3.0              NaN

# %%
df.describe()
# Out:
#         EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# count  4410.000000              4385.000000      4390.000000      4372.000000
# mean   2205.500000                 2.723603         2.728246         2.761436
# std    1273.201673                 1.092756         1.101253         0.706245
# min       1.000000                 1.000000         1.000000         1.000000
# 25%    1103.250000                 2.000000         2.000000         2.000000
# 50%    2205.500000                 3.000000         3.000000         3.000000
# 75%    3307.750000                 4.000000         4.000000         3.000000
# max    4410.000000                 4.000000         4.000000         4.000000

# %%
df.shape
# Out:
# (4410, 4)

# %%
df.loc[1:4]
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0

# %%
df.iloc[2:8]
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0
# 5           6                      3.0              2.0              2.0
# 6           7                      1.0              3.0              1.0
# 7           8                      1.0              2.0              3.0

# %%
df.isnull().sum()
# Out:
# EmployeeID                  0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# dtype: int64

# %%
df.isnull()
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0          False                    False            False            False
# 1          False                    False            False            False
# 2          False                    False            False            False
# 3          False                    False            False            False
# 4          False                    False            False            False
# ...          ...                      ...              ...              ...
# 4405       False                    False            False            False
# 4406       False                    False            False            False
# 4407       False                    False            False            False
# 4408       False                    False            False            False
# 4409       False                    False            False             True
#
# [4410 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['EmployeeID', 'EnvironmentSatisfaction', 'JobSatisfaction',
#        'WorkLifeBalance'],
#       dtype='object')

# %%
columns = ['EmployeeID', 'EnvironmentSatisfaction', 'JobSatisfaction',
       'WorkLifeBalance']

# %%
for col in columns:
    df[col] = df[col].fillna(df[col].median())

# %%
df.isnull().sum()
# Out:
# EmployeeID                 0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# dtype: int64

# %%
numeric_cols=df.select_dtypes(include="number").columns

# %%
sns.histplot(df["EmployeeID"],bins = 10,kde=True)
plt.title("EmployeeID")
# Out:
# Text(0.5, 1.0, 'EmployeeID')

# %%
sns.histplot(df["EnvironmentSatisfaction"],bins=10,kde=True)
plt.title("EnvironmentSatisfaction")
# Out:
# Text(0.5, 1.0, 'EnvironmentSatisfaction')

# %%
sns.histplot(df["JobSatisfaction"],bins=20,kde=True)
plt.title("JobSatisfaction")
# Out:
# Text(0.5, 1.0, 'JobSatisfaction')

# %%
sns.histplot(df["WorkLifeBalance"],bins=10,kde=True)
plt.title("WorkLifeBalance")
# Out:
# Text(0.5, 1.0, 'WorkLifeBalance')

# %%
from scipy.stats import zscore
z_scores = df[['EmployeeID', 'EnvironmentSatisfaction', 'JobSatisfaction','WorkLifeBalance']].apply(zscore)

# %%
z_scores > 3
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0          False                    False            False            False
# 1          False                    False            False            False
# 2          False                    False            False            False
# 3          False                    False            False            False
# 4          False                    False            False            False
# ...          ...                      ...              ...              ...
# 4405       False                    False            False            False
# 4406       False                    False            False            False
# 4407       False                    False            False            False
# 4408       False                    False            False            False
# 4409       False                    False            False            False
#
# [4410 rows x 4 columns]

# %%
outliers= (z_scores < -3) | (z_scores > 3)

# %%
total_outliers = outliers.sum()

# %%
print(total_outliers)
# Out:
# EmployeeID                 0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# dtype: int64

# %%
columns = ['EmployeeID', 'EnvironmentSatisfaction']
for col in columns:
    Q1=df[col].quantile(0.25)
    Q3=df[col].quantile(0.75)
    IQR=Q3-Q1                             # (Interquartile Range)

    LOWER_BOUND = Q1-1.5*IQR
    UPPER_BOUND = Q3+1.5*IQR
    outliers = df[(df[col] < LOWER_BOUND) | (df[col] > UPPER_BOUND)]

    print(outliers.shape[0])
# Out:
# 0
# 0

# %%
columns = ['JobSatisfaction','WorkLifeBalance']
for col in columns:
    Q1=df[col].quantile(0.25)
    Q3=df[col].quantile(0.75)
    IQR=Q3-Q1

    LOWER_BOUND = Q1-1.5*IQR
    UPPER_BOUND = Q3+1.5*IQR
    outliers = df[(df[col] < LOWER_BOUND) | (df[col] > UPPER_BOUND)]

    print(outliers.shape[0])
# Out:
# 0
# 0

# %%
df = pd.read_csv("employee_survey_data.csv")

# %%
df[df.isnull().any(axis=1)]
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 11            12                      NaN              4.0              3.0
# 40            41                      3.0              NaN              3.0
# 84            85                      3.0              4.0              NaN
# 111          112                      NaN              2.0              3.0
# 124          125                      3.0              NaN              3.0
# ...          ...                      ...              ...              ...
# 4219        4220                      2.0              NaN              3.0
# 4305        4306                      2.0              2.0              NaN
# 4332        4333                      NaN              4.0              3.0
# 4345        4346                      4.0              NaN              4.0
# 4409        4410                      1.0              3.0              NaN
#
# [83 rows x 4 columns]

# %%
df[df['EnvironmentSatisfaction'].isnull()]
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 11            12                      NaN              4.0              3.0
# 111          112                      NaN              2.0              3.0
# 195          196                      NaN              3.0              2.0
# 300          301                      NaN              4.0              3.0
# 405          406                      NaN              4.0              2.0
# 489          490                      NaN              4.0              3.0
# 678          679                      NaN              2.0              3.0
# 846          847                      NaN              3.0              2.0
# 909          910                      NaN              4.0              2.0
# 1077        1078                      NaN              4.0              3.0
# 1224        1225                      NaN              3.0              2.0
# ...

# %%
df[df['JobSatisfaction'].isnull()]
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 40            41                      3.0              NaN              3.0
# 124          125                      3.0              NaN              3.0
# 313          314                      1.0              NaN              3.0
# 586          587                      3.0              NaN              3.0
# 859          860                      2.0              NaN              2.0
# 1195        1196                      2.0              NaN              2.0
# 1468        1469                      4.0              NaN              3.0
# 1678        1679                      2.0              NaN              3.0
# 1909        1910                      3.0              NaN              3.0
# 2182        2183                      3.0              NaN              3.0
# 2476        2477                      3.0              NaN              3.0
# ...

# %%
df[df['WorkLifeBalance'].isnull()]
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 84            85                      3.0              4.0              NaN
# 273          274                      3.0              4.0              NaN
# 483          484                      4.0              3.0              NaN
# 609          610                      4.0              1.0              NaN
# 735          736                      1.0              3.0              NaN
# 861          862                      3.0              2.0              NaN
# 987          988                      1.0              4.0              NaN
# 1092        1093                      1.0              3.0              NaN
# 1197        1198                      3.0              3.0              NaN
# 1260        1261                      1.0              4.0              NaN
# 1323        1324                      1.0              3.0              NaN
# ...

# %%
import pandas as pd
df = pd.read_csv("employee_survey_data.csv")

# %%
df= df.reset_index(drop=True)

# %%
df.to_csv("cleaned_employee_survey_data.csv",index=False)

# %%
print("\ncleaned dataset shape:",df.shape)
# Out:
# cleaned dataset shape: (4410, 4)
